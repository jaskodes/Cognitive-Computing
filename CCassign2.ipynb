# %%
roll_no = input("Enter your roll number: ")
digits = [int(digit) for digit in roll_no] 
L = [digit * 10 for digit in digits]
# Out:
# Enter your roll number:  1024160033

# %%
print("The list of digits multiplied by 10 is:", L)
# Out:
# The list of digits multiplied by 10 is: [10, 0, 20, 40, 10, 60, 0, 0, 30, 30]

# %%
L.append(50)

# %%
L.append(50)

print("After append:", L)
# Out:
# After append: [10, 0, 20, 40, 10, 60, 0, 0, 30, 30, 50, 50]

# %%
L.insert(2, 70)

print("After insert:", L)
# Out:
# After insert: [10, 0, 70, 20, 40, 10, 60, 0, 0, 30, 30, 50, 50]

# %%
L.remove(50)

print("After remove:", L)
# Out:
# After remove: [10, 0, 70, 20, 40, 10, 60, 0, 0, 30, 30, 50]

# %%
removed = L.pop()

print("Removed element:", removed)
print("After pop:", L)
# Out:
# Removed element: 50
# After pop: [10, 0, 70, 20, 40, 10, 60, 0, 0, 30, 30]

# %%
L.sort()

print("Ascending order:", L)
# Out:
# Ascending order: [0, 0, 0, 10, 10, 20, 30, 30, 40, 60, 70]

# %%
L.sort(reverse=True)

print("Descending order:", L)
# Out:
# Descending order: [70, 60, 40, 30, 30, 20, 10, 10, 0, 0, 0]

# %%
print("First three elements:", L[:3])
print("Last three elements:", L[-3:])
# Out:
# First three elements: [70, 60, 40]
# Last three elements: [0, 0, 0]

# %%
average = sum(L) / len(L)

greater = [x for x in L if x > average]

print("Average:", average)
print("Elements greater than average:", greater)
# Out:
# Average: 24.545454545454547
# Elements greater than average: [70, 60, 40, 30, 30]

# %%
scores = tuple(L[:8])

print("Scores:", scores)
# Out:
# Scores: (70, 60, 40, 30, 30, 20, 10, 10)

# %%
highest_score=max(scores)
highest_index = scores.index(highest_score)
print("Highest score:", highest_score)  
print("Index of highest score:", highest_index)
# Out:
# Highest score: 70
# Index of highest score: 0

# %%
lowest = min(scores)
lowest_count = scores.count(lowest)

print("Lowest score:", lowest)
print("Number of times lowest appears:", lowest_count)
# Out:
# Lowest score: 10
# Number of times lowest appears: 2

# %%
reversed_scores = list(reversed(scores))

print("Reversed tuple as list:", reversed_scores)
# Out:
# Reversed tuple as list: [10, 10, 20, 30, 30, 40, 60, 70]

# %%
score = int(input("Enter a score: "))

if score in scores:
    print("First occurrence index:", scores.index(score))
else:
    print("Score is not present in the tuple.")
# Out:
# Enter a score:  100
# Score is not present in the tuple.

# %%
scores[0] = 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 scores[0] = 100
#
# TypeError: 'tuple' object does not support item assignment

# %%
try:
    scores[0] = 100
except TypeError as e:
    
    print("Error:", e)
    print("Tuple cannot be modified because it is immutable.")
# Out:
# Error: 'tuple' object does not support item assignment
# Tuple cannot be modified because it is immutable.

# %%
first_score, second_score, *remaining_scores = scores

print("First score:", first_score)
print("Second score:", second_score)
print("Remaining scores:", remaining_scores)
# Out:
# First score: 70
# Second score: 60
# Remaining scores: [40, 30, 30, 20, 10, 10]

# %%
import random

roll_no = int(input("Enter your roll number: "))

random.seed(roll_no)
# Out:
# Enter your roll number:  1024160033

# %%
numbers = [random.randint(100, 900) for _ in range(100)]

print(numbers)
# Out:
# [442, 383, 164, 660, 177, 713, 415, 134, 608, 587, 433, 558, 399, 488, 543, 289, 564, 449, 311, 710, 486, 262, 131, 603, 337, 353, 893, 886, 747, 842, 277, 716, 252, 296, 600, 310, 158, 480, 135, 139, 663, 514, 319, 868, 714, 229, 283, 355, 458, 114, 147, 687, 251, 790, 720, 694, 105, 387, 225, 729, 645, 162, 473, 866, 795, 282, 446, 528, 604, 269, 718, 796, 545, 301, 328, 562, 139, 262, 582, 554, 860, 707, 689, 864, 678, 375, 388, 469, 808, 819, 366, 417, 792, 639, 394, 835, 782, 533, 361, 350]

# %%
odd_numbers = [x for x in numbers if x % 2 != 0]

print("Odd numbers:", odd_numbers)
print("Count of odd numbers:", len(odd_numbers))
# Out:
# Odd numbers: [383, 177, 713, 415, 587, 433, 399, 543, 289, 449, 311, 131, 603, 337, 353, 893, 747, 277, 135, 139, 663, 319, 229, 283, 355, 147, 687, 251, 105, 387, 225, 729, 645, 473, 795, 269, 545, 301, 139, 707, 689, 375, 469, 819, 417, 639, 835, 533, 361]
# Count of odd numbers: 49

# %%
even_numbers = [x for x in numbers if x % 2 == 0]

print("Even numbers:", even_numbers)
print("Count of even numbers:", len(even_numbers))
# Out:
# Even numbers: [442, 164, 660, 134, 608, 558, 488, 564, 710, 486, 262, 886, 842, 716, 252, 296, 600, 310, 158, 480, 514, 868, 714, 458, 114, 790, 720, 694, 162, 866, 282, 446, 528, 604, 718, 796, 328, 562, 262, 582, 554, 860, 864, 678, 388, 808, 366, 792, 394, 782, 350]
# Count of even numbers: 51

# %%
def is_prime(n):
    if n < 2:
        return False

    for i in range(2, int(n ** 0.5) + 1):
        if n % i == 0:
            return False

    return True

# %%
prime_numbers = [x for x in numbers if is_prime(x)]

print("Prime numbers:", prime_numbers)
print("Count of prime numbers:", len(prime_numbers))
# Out:
# Prime numbers: [383, 587, 433, 449, 311, 131, 337, 353, 277, 139, 229, 283, 251, 269, 139]
# Count of prime numbers: 15

# %%
frequency = {}

for x in numbers:
    frequency[x] = frequency.get(x, 0) + 1

print(frequency)
# Out:
# {442: 1, 383: 1, 164: 1, 660: 1, 177: 1, 713: 1, 415: 1, 134: 1, 608: 1, 587: 1, 433: 1, 558: 1, 399: 1, 488: 1, 543: 1, 289: 1, 564: 1, 449: 1, 311: 1, 710: 1, 486: 1, 262: 2, 131: 1, 603: 1, 337: 1, 353: 1, 893: 1, 886: 1, 747: 1, 842: 1, 277: 1, 716: 1, 252: 1, 296: 1, 600: 1, 310: 1, 158: 1, 480: 1, 135: 1, 139: 2, 663: 1, 514: 1, 319: 1, 868: 1, 714: 1, 229: 1, 283: 1, 355: 1, 458: 1, 114: 1, 147: 1, 687: 1, 251: 1, 790: 1, 720: 1, 694: 1, 105: 1, 387: 1, 225: 1, 729: 1, 645: 1, 162: 1, 473: 1, 866: 1, 795: 1, 282: 1, 446: 1, 528: 1, 604: 1, 269: 1, 718: 1, 796: 1, 545: 1, 301: 1, 328: 1, 562: 1, 582: 1, 554: 1, 860: 1, 707: 1, 689: 1, 864: 1, 678: 1, 375: 1, 388: 1, 469: 1, 808: 1, 819: 1, 366: 1, 417: 1, 792: 1, 639: 1, 394: 1, 835: 1, 782: 1, 533: 1, 361: 1, 350: 1}

# %%
most_frequent = max(frequency, key=frequency.get)

print("Most frequent number:", most_frequent)
print("Number of times it occurs:", frequency[most_frequent])
# Out:
# Most frequent number: 262
# Number of times it occurs: 2

# %%
roll_no = input("Enter your roll number: ")

digits = [int(digit) for digit in roll_no]

print("Digits:", digits)
# Out:
# Enter your roll number:  1024160033
# Digits: [1, 0, 2, 4, 1, 6, 0, 0, 3, 3]

# %%
A = {digit * 7 for digit in digits}
B = {digit * 9 for digit in digits}

print("Set A:", A)
print("Set B:", B)
# Out:
# Set A: {0, 7, 42, 14, 21, 28}
# Set B: {0, 36, 9, 18, 54, 27}

# %%
union = A.union(B)

print("Union:", union)
# Out:
# Union: {0, 36, 7, 9, 42, 14, 18, 21, 54, 27, 28}

# %%
intersection = A.intersection(B)

print("Intersection:", intersection)
# Out:
# Intersection: {0}

# %%
A_minus_B = A.difference(B)

print("A - B:", A_minus_B)
# Out:
# A - B: {7, 42, 14, 21, 28}

# %%
B_minus_A = B.difference(A)

print("B - A:", B_minus_A)
# Out:
# B - A: {36, 9, 18, 54, 27}

# %%
symmetric_difference = A.symmetric_difference(B)

print("Symmetric Difference:", symmetric_difference)
# Out:
# Symmetric Difference: {7, 9, 14, 18, 21, 27, 28, 36, 42, 54}

# %%
print("Is A a subset of B?", A.issubset(B))
# Out:
# Is A a subset of B? False

# %%
print("Is B a superset of A?", B.issuperset(A))
# Out:
# Is B a superset of A? False

# %%
X = int(input("Enter a value X: "))

A.discard(X)

print("Set A after discard:", A)
# Out:
# Enter a value X:  100
# Set A after discard: {0, 7, 42, 14, 21, 28}

# %%
my_dict = {
    "name": "Jaskaran Singh",
    "roll_no": "1024160033",
    "branch": "CSE",
    "age": 19,
    "city": "CHD"
}

print(my_dict)
# Out:
# {'name': 'Jaskaran Singh', 'roll_no': '1024160033', 'branch': 'CSE', 'age': 19, 'city': 'CHD'}

# %%
my_dict["location"] = my_dict.pop("city")

print(my_dict)
# Out:
# {'name': 'Jaskaran Singh', 'roll_no': '1024160033', 'branch': 'CSE', 'age': 19, 'location': 'CHD'}

# %%
my_dict["cgpa"] = 8.08

print(my_dict)
# Out:
# {'name': 'Jaskaran Singh', 'roll_no': '1024160033', 'branch': 'CSE', 'age': 19, 'location': 'CHD', 'cgpa': 8.08}

# %%
my_dict["age"] = my_dict["age"] + 1

print(my_dict)
# Out:
# {'name': 'Jaskaran Singh', 'roll_no': '1024160033', 'branch': 'CSE', 'age': 20, 'location': 'CHD', 'cgpa': 8.08}

# %%
dict_pop = my_dict.copy()

removed_value = dict_pop.pop("branch")

print("Dictionary:", dict_pop)
print("Removed value:", removed_value)
# Out:
# Dictionary: {'name': 'Jaskaran Singh', 'roll_no': '1024160033', 'age': 20, 'location': 'CHD', 'cgpa': 8.08}
# Removed value: CSE

# %%
dict_del = my_dict.copy()

del dict_del["branch"]

print("Dictionary:", dict_del)
# Out:
# Dictionary: {'name': 'Jaskaran Singh', 'roll_no': '1024160033', 'age': 20, 'location': 'CHD', 'cgpa': 8.08}

# %%
for key, value in my_dict.items():
    print(key, "→", value)
# Out:
# name → Jaskaran Singh
# roll_no → 1024160033
# branch → CSE
# age → 20
# location → CHD
# cgpa → 8.08

# %%
if "email" in my_dict:
    print("Email:", my_dict["email"])
else:
    print("Email does not exist in the dictionary.")
# Out:
# Email does not exist in the dictionary.

# %%
friend_dict = {
    "name": "geet rawal",
    "roll_no": "1024160012",
    "branch": "CSE",
    "age": 20,
    "city": "ludhiana"
}

print(friend_dict)
# Out:
# {'name': 'geet rawal', 'roll_no': '1024160012', 'branch': 'CSE', 'age': 20, 'city': 'ludhiana'}

# %%
merged_dict = {**my_dict, **friend_dict}

print("Merged dictionary:", merged_dict)
# Out:
# Merged dictionary: {'name': 'geet rawal', 'roll_no': '1024160012', 'branch': 'CSE', 'age': 20, 'location': 'CHD', 'cgpa': 8.08, 'city': 'ludhiana'}

# %%
string_values = {
    key: value
    for key, value in my_dict.items()
    if isinstance(value, str)
}

print("String values:", string_values)
# Out:
# String values: {'name': 'Jaskaran Singh', 'roll_no': '1024160033', 'branch': 'CSE', 'location': 'CHD'}
